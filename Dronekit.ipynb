# %% [markdown]
# # Dronekit 环境部署

# %% [markdown]
# 参考：https://www.ncnynl.com/archives/202106/4255.html

# %% [markdown]
# ## 1. 构建Dronekit虚拟环境，使用Python3.10

# %%
# !git clone https://github.com/Archiconda/build-tools/releases
# !conda create -n  dronekit_env python=3.10
# !conda activate dronekit_env

# %% [markdown]
# ## 2. 安装必要包

# %%
# nano端使用
# !pip install dronekit

# pymanlink是通信协议，mavlink的python版本
# !pip install pymavlink

# PC端使用dronekit-sitl
# !pip install dronekit-sitl

# mavproxy是一个类似地面站

# %% [markdown]
# ## 3. 编译ArduPilot

# %%
# 下载ardupilot
# !git clone https://github.com/ArduPilot/ardupilot
# %cd ardupilot
#更新程序子模块 
# !git submodule update --init --recursive

# %% [raw]
# 系统编译

# %%
# %cd ~/ardupilot
# Out:
# /home/jetson/ardupilot

# %%
# 查看所有支持的飞控类型
# !./waf list_boards
# Out:
# aero AeroFox-Airspeed AeroFox-Airspeed-DLVR AeroFox-PMU airbotf4 AIRLink ARK_GPS ARK_RTK_GPS ARKV6X AtomRCF405NAVI bbbmini BeastF7 BeastF7v2 BeastH7 BeastH7v2 bebop bhat BirdCANdy blue C-RTK2-HP CarbonixF405 CarbonixL496 crazyflie2 CUAV-Nora CUAV-Nora-bdshot CUAV-X7 CUAV-X7-bdshot CUAV_GPS CUAVv5 CUAVv5-bdshot CUAVv5Nano CUAVv5Nano-bdshot CubeBlack CubeBlack+ CubeBlack-periph CubeGreen-solo CubeOrange CubeOrange-bdshot CubeOrange-joey CubeOrange-ODID CubeOrange-periph CubeOrange-periph-heavy CubeOrange-SimOnHardWare CubeOrangePlus CubeOrangePlus-bdshot CubeOrangePlus-SimOnHardWare CubePilot-CANMod CubePurple CubeRedPrimary CubeRedSecondary CubeSolo CubeYellow CubeYellow-bdshot dark DevEBoxH7v2 disco DrotekP3Pro Durandal Durandal-bdshot edge erleboard erlebrain2 esp32buzz esp32diy esp32empty esp32icarus esp32nick esp32tomte76 f103-ADSB f103-Airspeed f103-GPS f103-HWESC f103-QiotekPeriph f103-RangeFinder f103-Trigger f303-GPS f303-HWESC f303-M10025 f303-M10070 f303-MatekGPS f303-PWM f303-TempSensor f303-Universal F35Lightning f405-MatekAirspeed f405-MatekGPS F4BY FlyingMoonF407 FlyingMoonF427 FlywooF405S-AIO FlywooF745 FlywooF745Nano fmuv2 fmuv3 fmuv3-bdshot fmuv5 FoxeerH743v1 FreeflyRTK G4-ESC H757I_EVAL H757I_EVAL_intf HerePro Hitec-Airspeed HitecMosaic HolybroG4_Compass HolybroG4_GPS HolybroGPS iomcu iomcu_f103_8MHz JFB100 JHEMCU-GSF405A JHEMCU-GSF405A-RX2 KakuteF4 KakuteF4Mini KakuteF7 KakuteF7-bdshot KakuteF7Mini KakuteH7 KakuteH7-bdshot KakuteH7Mini KakuteH7Mini-Nand KakuteH7v2 linux luminousbee4 luminousbee5 MambaF405-2022 MambaF405US-I2C MambaF405v2 MambaH743v4 MatekF405 MatekF405-bdshot MatekF405-CAN MatekF405-STD MatekF405-TE MatekF405-TE-bdshot MatekF405-Wing MatekF405-Wing-bdshot MatekF765-SE MatekF765-Wing MatekF765-Wing-bdshot MatekH743 MatekH743-bdshot MatekH743-periph MatekL431-Airspeed MatekL431-BattMon MatekL431-bdshot MatekL431-DShot MatekL431-EFI MatekL431-GPS MatekL431-HWTelem MatekL431-Periph MatekL431-Proximity MatekL431-Rangefinder MazzyStarDrone mindpx-v2 mini-pix modalai_fc-v1 mRo-M10095 mRoCANPWM-M10126 mRoControlZeroClassic mRoControlZeroF7 mRoControlZeroH7 mRoControlZeroH7-bdshot mRoControlZeroOEMH7 mRoNexus mRoPixracerPro mRoPixracerPro-bdshot mRoX21 mRoX21-777 navigator navio navio2 Nucleo-G491 Nucleo-L476 Nucleo-L496 NucleoH743 NucleoH755 obal ocpoc_zynq omnibusf4 omnibusf4pro omnibusf4pro-bdshot omnibusf4pro-one omnibusf4v6 OMNIBUSF7V2 OmnibusNanoV6 OmnibusNanoV6-bdshot PH4-mini PH4-mini-bdshot Pix32v5 PixC4-Jetson PixFlamingo Pixhawk1 Pixhawk1-1M Pixhawk1-1M-bdshot Pixhawk4 Pixhawk4-bdshot Pixhawk5X Pixhawk6C Pixhawk6C-bdshot Pixhawk6X Pixhawk6X-ODID PixPilot-V3 PixPilot-V6 Pixracer Pixracer-bdshot Pixracer-periph PixSurveyA1 PixSurveyA1-IND PixSurveyA2 pocket pxf pxfmini QioTekZealotF427 QioTekZealotH743 QioTekZealotH743-bdshot R9Pilot ReaperF745 revo-mini revo-mini-bdshot revo-mini-i2c revo-mini-i2c-bdshot revo-mini-sd rFCU rGNSS rst_zynq Sierra-F405 Sierra-F412 Sierra-F9P Sierra-L431 sitl SITL_arm_linux_gnueabihf sitl_periph_gps SITL_static SITL_x86_64_linux_gnu SkystarsH7HD SkystarsH7HD-bdshot skyviper-f412-rev1 skyviper-journey skyviper-v2450 sparky2 speedybeef4 SpeedyBeeF405WING speedybeef4v3 SPRacingH7 SPRacingH7RF SuccexF4 Swan-K1 TBS-Colibri-F7 thepeach-k1 thepeach-r1 vnav VRBrain-v51 VRBrain-v52 VRBrain-v54 VRCore-v10 VRUBrain-v51 ZubaxGNSS zynq
# 'list_boards' finished successfully (0.013s)

# %%
# Pixhawk4版飞控，对应Pixhawk4硬件
# !./waf configure --board Pixhawk4
# Out:
# Setting top to                           : /home/jetson/ardupilot
# Setting out to                           : /home/jetson/ardupilot/build
# Autoconfiguration                        : enabled
# Checking for program 'python'            : /usr/bin/python3
# Checking for python version >= 3.6.9     : 3.8.10
# Setting board to                         : Pixhawk4
# Using toolchain                          : arm-none-eabi
# Checking for 'g++' (C++ compiler)        : /usr/lib/ccache/arm-none-eabi-g++
# Checking for 'gcc' (C compiler)          : /usr/lib/ccache/arm-none-eabi-gcc
# Checking for c flags '-MMD'              : yes
# Checking for cxx flags '-MMD'            : yes
# CXX Compiler                             : g++ 10.2.1
# Checking for program 'make'              : /usr/bin/make
# Checking for program 'arm-none-eabi-objcopy' : /opt/gcc-arm-none-eabi-10-2020-q4-major/bin/arm-none-eabi-objcopy
# Including /home/jetson/ardupilot/libraries/AP_HAL_ChibiOS/hwdef/fmuv5/hwdef.dat
# Adding environment OPTIMIZE -O2
# Removing PB1
# Removing PC7
# Removing HAL_BATT_VOLT_SCALE
# Removing HAL_BATT_CURR_SCALE
# Setup for MCU STM32F767xx
# Writing hwdef setup in /home/jetson/ardupilot/build/Pixhawk4/hwdef.h
# MCU Flags: cortex-m7 ['-mcpu=cortex-m7', '-mfpu=fpv5-d16', '-mfloat-abi=hard']
# Writing DMA map
# Setting up as normal firmware
# Generating ldscript.ld
# Default parameters path from hwdef: /home/jetson/ardupilot/libraries/AP_HAL_ChibiOS/hwdef/Pixhawk4/defaults.parm
# Checking for env.py
# env set OPTIMIZE=-O2
# env set ENABLE_DFU_BOOT=0
# env set WITH_FATFS=1
# env set PROCESS_STACK=0x1C00
# env set MAIN_STACK=0x600
# env set IOMCU_FW=0
# env set PERIPH_FW=0
# env set HAL_NUM_CAN_IFACES=2
# env set HAL_CANFD_SUPPORTED=0
# env set BOARD_FLASH_SIZE=2048
# env set EXT_FLASH_SIZE_MB=0
# env set INT_FLASH_PRIMARY=False
# env set ENABLE_CRASHDUMP=1
# env set APP_RAM_START=None
# env set CPU_FLAGS=['-mcpu=cortex-m7', '-mfpu=fpv5-d16', '-mfloat-abi=hard', '-DARM_MATH_CM7', '-u_printf_float']
# env set CORTEX=cortex-m7
# env set APJ_BOARD_ID=50
# env set APJ_BOARD_TYPE=STM32F767xx
# env set USBID=0x1209/0x5740
# env set FLASH_RESERVE_START_KB=32
# env set EXT_FLASH_RESERVE_START_KB=0
# env set FLASH_TOTAL=2064384
# env set HAS_EXTERNAL_FLASH_SECTIONS=0
# env set DEFAULT_PARAMETERS=/home/jetson/ardupilot/libraries/AP_HAL_ChibiOS/hwdef/Pixhawk4/defaults.parm
# env set CHIBIOS_BUILD_FLAGS=USE_FATFS=yes CHIBIOS_STARTUP_MK=os/common/startup/ARMCMx/compilers/GCC/mk/startup_stm32f7xx.mk CHIBIOS_PLATFORM_MK=os/hal/ports/STM32/STM32F7xx/platform.mk MCU=cortex-m7 ENV_UDEFS=-DCHPRINTF_USE_FLOAT=1
# Enabling ChibiOS asserts                     : no
# Disabling Watchdog                           : no
# Enabling malloc guard                        : no
# Enabling ChibiOS thread statistics           : no
# Enabling -Werror                             : yes
# Checking for intelhex module:                : OK
# Enabled OpenDroneID                          : no
# Enabled firmware ID checking                 : no
# GPS Debug Logging                            : no
# Enabled custom controller                    : no
# Checking for HAVE_CMATH_ISFINITE             : yes
# Checking for HAVE_CMATH_ISINF                : yes
# Checking for HAVE_CMATH_ISNAN                : yes
# Checking for NEED_CMATH_ISFINITE_STD_NAMESPACE : yes
# Checking for NEED_CMATH_ISINF_STD_NAMESPACE    : yes
# Checking for NEED_CMATH_ISNAN_STD_NAMESPACE    : yes
# Checking for header endian.h                   : not found
# Checking for header byteswap.h                 : not found
# Checking for HAVE_MEMRCHR                      : no
# Configured VSCode Intellisense:                : no
# DC_DSDL compiler                               : /home/jetson/ardupilot/modules/DroneCAN/dronecan_dsdlc/dronecan_dsdlc.py
# Source is git repository                       : yes
# Update submodules                              : yes
# Checking for program 'git'                     : /usr/bin/git
# Gtest                                          : STM32 boards currently don't support compiling gtest
# Checking for program 'arm-none-eabi-size'      : /opt/gcc-arm-none-eabi-10-2020-q4-major/bin/arm-none-eabi-size
# Benchmarks                                     : disabled
# Unit tests                                     : disabled
# Scripting                                      : enabled
# Scripting runtime checks                       : enabled
# Debug build                                    : disabled
# Coverage build                                 : disabled
# Force 32-bit build                             : disabled
# Checking for program 'rsync'                   : /usr/bin/rsync
# 'configure' finished successfully (9.865s)

# %%
# 多旋翼固件
# !./waf copter
# Out:
# Waf: Entering directory `/home/jetson/ardupilot/build/Pixhawk4'
# Checking for env.py
# env added OPTIMIZE=-O2
# env added ENABLE_DFU_BOOT=0
# env added WITH_FATFS=1
# env added PROCESS_STACK=0x1C00
# env added MAIN_STACK=0x600
# env added IOMCU_FW=0
# env added PERIPH_FW=0
# env added HAL_NUM_CAN_IFACES=2
# env added HAL_CANFD_SUPPORTED=0
# env added BOARD_FLASH_SIZE=2048
# env added EXT_FLASH_SIZE_MB=0
# env added INT_FLASH_PRIMARY=False
# env added ENABLE_CRASHDUMP=1
# env appended APP_RAM_START=None
# env appended CPU_FLAGS=['-mcpu=cortex-m7', '-mfpu=fpv5-d16', '-mfloat-abi=hard', '-DARM_MATH_CM7', '-u_printf_float']
# env added CORTEX=cortex-m7
# env added APJ_BOARD_ID=50
# env added APJ_BOARD_TYPE=STM32F767xx
# env added USBID=0x1209/0x5740
# env added FLASH_RESERVE_START_KB=32
# env added EXT_FLASH_RESERVE_START_KB=0
# env added FLASH_TOTAL=2064384
# env added HAS_EXTERNAL_FLASH_SECTIONS=0
# env added DEFAULT_PARAMETERS=/home/jetson/ardupilot/libraries/AP_HAL_ChibiOS/hwdef/Pixhawk4/defaults.parm
# env added CHIBIOS_BUILD_FLAGS=USE_FATFS=yes CHIBIOS_STARTUP_MK=os/common/startup/ARMCMx/compilers/GCC/mk/startup_stm32f7xx.mk CHIBIOS_PLATFORM_MK=os/hal/ports/STM32/STM32F7xx/platform.mk MCU=cortex-m7 ENV_UDEFS=-DCHPRINTF_USE_FLOAT=1
# Embedding file bootloader.bin:/home/jetson/ardupilot/Tools/bootloaders/Pixhawk4_bl.bin
# Embedding file hwdef.dat:/home/jetson/ardupilot/build/Pixhawk4/hw.dat
# Embedding file io_firmware.bin:Tools/IO_Firmware/iofirmware_lowpolh.bin
# [ 3/10] Creating build/Pixhawk4/hwdef.h
# [ 4/10] Creating build/Pixhawk4/modules/ChibiOS/include_dirs
# Including /home/jetson/ardupilot/libraries/AP_HAL_ChibiOS/hwdef/fmuv5/hwdef.dat
# Adding environment OPTIMIZE -O2
# Removing PB1
# Removing PC7
# Removing HAL_BATT_VOLT_SCALE
# Removing HAL_BATT_CURR_SCALE
# Setup for MCU STM32F767xx
# Writing hwdef setup in /home/jetson/ardupilot/build/Pixhawk4/hwdef.h
# MCU Flags: cortex-m7 ['-mcpu=cortex-m7', '-mfpu=fpv5-d16', '-mfloat-abi=hard']
# Writing DMA map
# Setting up as normal firmware
# No change in hwdef.h
# Generating ldscript.ld
# Default parameters path from hwdef: /home/jetson/ardupilot/libraries/AP_HAL_ChibiOS/hwdef/Pixhawk4/defaults.parm
#
# [ 5/10] Compiling libraries/AP_Scripting/generator/src/main.c
# [ 6/10] Processing modules/mavlink/message_definitions/v1.0/all.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/all.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/all.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/ardupilotmega.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/ardupilotmega.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/ASLUAV.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/ASLUAV.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/common.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/common.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/development.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/development.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/icarous.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/icarous.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/minimal.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/minimal.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/python_array_test.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/python_array_test.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/standard.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/standard.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/test.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/test.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/ualberta.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/ualberta.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/uAvionix.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/uAvionix.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/loweheiser.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/loweheiser.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/storm32.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/storm32.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/AVSSUAS.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/AVSSUAS.xml
# Validation skipped for /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/cubepilot.xml.
# Parsing /home/jetson/ardupilot/modules/mavlink/message_definitions/v1.0/cubepilot.xml
# Merged enum MAV_CMD
# Merged enum MAV_CMD
# Merged enum MAV_CMD
# Merged enum MAV_CMD
# Merged enum MAV_CMD
# Found 332 MAVLink message types in 16 XML files
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/all
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/ardupilotmega
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/ASLUAV
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/common
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/development
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/icarous
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/minimal
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/python_array_test
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/standard
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/test
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/ualberta
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/uAvionix
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/loweheiser
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/storm32
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/AVSSUAS
# Generating C implementation in directory /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0/cubepilot
# Copying fixed headers for protocol 2.0 to /home/jetson/ardupilot/build/Pixhawk4/libraries/GCS_MAVLink/include/mavlink/v2.0
# [ 7/10] Processing dronecangen: modules/DroneCAN/DSDL/ardupilot modules/DroneCAN/DSDL/com modules/DroneCAN/DSDL/cuav modules/DroneCAN/DSDL/dronecan modules/DroneCAN/DSDL/mppt modules/DroneCAN/DSDL/uavcan
# [ 8/10] Creating build/Pixhawk4/ap_version.h
# [ 9/10] Linking build/Pixhawk4/modules/ChibiOS/libch.a
# expanding ardupilot.equipment.proximity_sensor.Proximity
# expanding ardupilot.equipment.trafficmonitor.TrafficReport
# expanding ardupilot.gnss.MovingBaselineData
# expanding ardupilot.indication.SafetyState
# expanding ardupilot.indication.Button
# expanding com.himark.servo.ServoCmd
# expanding com.himark.servo.ServoInfo
# expanding dronecan.sensors.hygrometer.Hygrometer
# expanding dronecan.remoteid.SelfID
# expanding dronecan.remoteid.SecureCommand
# expanding mppt.OutputEnable
# expanding uavcan.Timestamp
# expanding uavcan.protocol.GlobalTimeSync
# expanding uavcan.protocol.Panic
# expanding uavcan.protocol.GetTransportStats
# expanding uavcan.protocol.GetDataTypeInfo
# expanding uavcan.protocol.CANIfaceStats
# expanding uavcan.protocol.AccessCommandShell
# expanding uavcan.protocol.param.NumericValue
# expanding uavcan.protocol.param.GetSet
# expanding uavcan.protocol.file.EntryType
# expanding uavcan.protocol.file.BeginFirmwareUpdate
# expanding uavcan.protocol.file.GetDirectoryEntryInfo
# expanding uavcan.protocol.file.Delete
# expanding uavcan.protocol.debug.LogLevel
# expanding uavcan.protocol.debug.LogMessage
# expanding uavcan.protocol.debug.KeyValue
# expanding uavcan.protocol.enumeration.Indication
# expanding uavcan.protocol.dynamic_node_id.server.RequestVote
# expanding uavcan.protocol.dynamic_node_id.server.Discovery
# expanding uavcan.equipment.esc.RPMCommand
# expanding uavcan.equipment.esc.Status
# expanding uavcan.equipment.device.Temperature
# expanding uavcan.equipment.power.PrimaryPowerSupplyStatus
# expanding uavcan.equipment.gnss.RTCMStream
# expanding uavcan.equipment.gnss.ECEFPositionVelocity
# expanding uavcan.equipment.gnss.Auxiliary
# expanding uavcan.equipment.actuator.ArrayCommand
# expanding uavcan.equipment.actuator.Status
# expanding uavcan.equipment.ice.reciprocating.Status
# expanding uavcan.equipment.camera_gimbal.Mode
# expanding uavcan.equipment.camera_gimbal.AngularCommand
# expanding uavcan.equipment.air_data.StaticTemperature
# expanding uavcan.equipment.air_data.RawAirData
# expanding uavcan.equipment.air_data.Sideslip
# expanding uavcan.equipment.hardpoint.Status
# expanding uavcan.equipment.hardpoint.Command
# expanding uavcan.equipment.ahrs.MagneticFieldStrength2
# expanding uavcan.equipment.indication.LightsCommand
# expanding uavcan.equipment.indication.RGB565
# expanding uavcan.tunnel.Call
# expanding uavcan.tunnel.Protocol
# expanding ardupilot.equipment.power.BatteryInfoAux
# expanding ardupilot.gnss.Status
# expanding ardupilot.gnss.RelPosHeading
# expanding ardupilot.gnss.Heading
# expanding ardupilot.indication.NotifyState
# expanding com.hex.equipment.flow.Measurement
# expanding com.volz.servo.ActuatorStatus
# expanding cuav.equipment.power.CBAT
# expanding dronecan.remoteid.ArmStatus
# expanding dronecan.remoteid.Location
# expanding dronecan.remoteid.System
# expanding dronecan.remoteid.BasicID
# expanding dronecan.remoteid.OperatorID
# expanding mppt.Stream
# expanding uavcan.CoarseOrientation
# expanding uavcan.protocol.RestartNode
# expanding uavcan.protocol.DataTypeKind
# expanding uavcan.protocol.GetNodeInfo
# expanding uavcan.protocol.SoftwareVersion
# expanding uavcan.protocol.NodeStatus
# expanding uavcan.protocol.HardwareVersion
# expanding uavcan.protocol.param.Value
# expanding uavcan.protocol.param.ExecuteOpcode
# expanding uavcan.protocol.param.Empty
# expanding uavcan.protocol.file.Error
# expanding uavcan.protocol.file.Path
# expanding uavcan.protocol.file.GetInfo
# expanding uavcan.protocol.file.Write
# expanding uavcan.protocol.file.Read
# expanding uavcan.protocol.enumeration.Begin
# expanding uavcan.protocol.dynamic_node_id.Allocation
# expanding uavcan.protocol.dynamic_node_id.server.Entry
# expanding uavcan.protocol.dynamic_node_id.server.AppendEntries
# expanding uavcan.equipment.esc.RawCommand
# expanding uavcan.equipment.power.CircuitStatus
# expanding uavcan.equipment.power.BatteryInfo
# expanding uavcan.equipment.gnss.Fix
# expanding uavcan.equipment.gnss.Fix2
# expanding uavcan.equipment.range_sensor.Measurement
# expanding uavcan.equipment.actuator.Command
# expanding uavcan.equipment.ice.FuelTankStatus
# expanding uavcan.equipment.ice.reciprocating.CylinderStatus
# expanding uavcan.equipment.camera_gimbal.GEOPOICommand
# expanding uavcan.equipment.camera_gimbal.Status
# expanding uavcan.equipment.safety.ArmingStatus
# expanding uavcan.equipment.air_data.TrueAirspeed
# expanding uavcan.equipment.air_data.StaticPressure
# expanding uavcan.equipment.air_data.IndicatedAirspeed
# expanding uavcan.equipment.air_data.AngleOfAttack
# expanding uavcan.equipment.ahrs.MagneticFieldStrength
# expanding uavcan.equipment.ahrs.Solution
# expanding uavcan.equipment.ahrs.RawIMU
# expanding uavcan.equipment.indication.SingleLightCommand
# expanding uavcan.equipment.indication.BeepCommand
# expanding uavcan.tunnel.Broadcast
# expanding uavcan.tunnel.SerialConfig
# expanding uavcan.navigation.GlobalNavigationSolution
#
# [10/10] Processing /home/jetson/ardupilot/build/Pixhawk4/libraries/AP_Scripting/lua_generated_bindings.cpp,/home/jetson/ardupilot/build/Pixhawk4/libraries/AP_Scripting/lua_generated_bindings.h: libraries/AP_Scripting/generator/description/bindings.desc build/Pixhawk4/gen-bindings -> build/Pixhawk4/libraries/AP_Scripting/lua_generated_bindings.cpp build/Pixhawk4/libraries/AP_Scripting/lua_generated_bindings.h
# [1/115] ChibiOS: Compiling crt0_v7m.S
# [2/115] ChibiOS: Compiling vectors.S
# [3/115] ChibiOS: Compiling chcoreasm.S
# [4/115] ChibiOS: Compiling ff.c
# [5/115] ChibiOS: Compiling ffunicode.c
# [6/115] ChibiOS: Compiling chcore.c
# [7/115] ChibiOS: Compiling crt1.c
# [8/115] ChibiOS: Compiling bufstreams.c
# [9/115] ChibiOS: Compiling chprintf.c
# [10/115] ChibiOS: Compiling chscanf.c
# [11/115] ChibiOS: Compiling memstreams.c
# [12/115] ChibiOS: Compiling nullstreams.c
# [13/115] ChibiOS: Compiling osal.c
# [14/115] ChibiOS: Compiling hal_adc_lld.c
# [15/115] ChibiOS: Compiling hal_can_lld.c
# [16/115] ChibiOS: Compiling hal_crypto_lld.c
# [17/115] ChibiOS: Compiling hal_dac_lld.c
# [18/115] ChibiOS: Compiling stm32_dma.c
# [19/115] ChibiOS: Compiling stm32_exti.c
# [20/115] ChibiOS: Compiling hal_pal_lld.c
# [21/115] ChibiOS: Compiling hal_i2c_lld.c
# [22/115] ChibiOS: Compiling hal_mac_lld.c
# [23/115] ChibiOS: Compiling hal_usb_lld.c
# [24/115] ChibiOS: Compiling hal_wspi_lld.c
# [25/115] ChibiOS: Compiling hal_trng_lld.c
# [26/115] ChibiOS: Compiling hal_rtc_lld.c
# [27/115] ChibiOS: Compiling hal_sdc_lld.c
# [28/115] ChibiOS: Compiling hal_i2s_lld.c
# [29/115] ChibiOS: Compiling hal_spi_lld.c
# [30/115] ChibiOS: Compiling hal_st_lld.c
# [31/115] ChibiOS: Compiling hal_eicu_lld.c
# [32/115] ChibiOS: Compiling hal_gpt_lld.c
# [33/115] ChibiOS: Compiling hal_icu_lld.c
# [34/115] ChibiOS: Compiling hal_pwm_lld.c
# [35/115] ChibiOS: Compiling hal_serial_lld.c
# [36/115] ChibiOS: Compiling hal_sio_lld.c
# [37/115] ChibiOS: Compiling hal_uart_lld.c
# [38/115] ChibiOS: Compiling hal_wdg_lld.c
# [39/115] ChibiOS: Compiling hal_lld.c
# [40/115] ChibiOS: Compiling stm32_isr.c
# [41/115] ChibiOS: Compiling nvic.c
# [42/115] ChibiOS: Compiling hal.c
# [43/115] ChibiOS: Compiling hal_adc.c
# [44/115] ChibiOS: Compiling hal_buffers.c
# [45/115] ChibiOS: Compiling hal_can.c
# [46/115] ChibiOS: Compiling hal_crypto.c
# [47/115] ChibiOS: Compiling hal_dac.c
# [48/115] ChibiOS: Compiling hal_efl.c
# [49/115] ChibiOS: Compiling hal_eicu.c
# [50/115] ChibiOS: Compiling hal_flash.c
# [51/115] ChibiOS: Compiling hal_gpt.c
# [52/115] ChibiOS: Compiling hal_i2c.c
# [53/115] ChibiOS: Compiling hal_i2s.c
# [54/115] ChibiOS: Compiling hal_icu.c
# [55/115] ChibiOS: Compiling hal_mac.c
# [56/115] ChibiOS: Compiling hal_mmc_spi.c
# [57/115] ChibiOS: Compiling hal_mmcsd.c
# [58/115] ChibiOS: Compiling hal_pal.c
# [59/115] ChibiOS: Compiling hal_pwm.c
# [60/115] ChibiOS: Compiling hal_queues.c
# [61/115] ChibiOS: Compiling hal_rtc.c
# [62/115] ChibiOS: Compiling hal_sdc.c
# [63/115] ChibiOS: Compiling hal_serial.c
# [64/115] ChibiOS: Compiling hal_serial_usb.c
# [65/115] ChibiOS: Compiling hal_sio.c
# [66/115] ChibiOS: Compiling hal_spi.c
# [67/115] ChibiOS: Compiling hal_st.c
# [68/115] ChibiOS: Compiling hal_trng.c
# [69/115] ChibiOS: Compiling hal_uart.c
# [70/115] ChibiOS: Compiling hal_usb.c
# [71/115] ChibiOS: Compiling hal_wdg.c
# [72/115] ChibiOS: Compiling hal_wspi.c
# [73/115] ChibiOS: Compiling chdelegates.c
# [74/115] ChibiOS: Compiling chfactory.c
# [75/115] ChibiOS: Compiling chmboxes.c
# [76/115] ChibiOS: Compiling chmemcore.c
# [77/115] ChibiOS: Compiling chmemheaps.c
# [78/115] ChibiOS: Compiling chmempools.c
# [79/115] ChibiOS: Compiling chobjcaches.c
# [80/115] ChibiOS: Compiling chpipes.c
# [81/115] ChibiOS: Compiling chcond.c
# [82/115] ChibiOS: Compiling chdebug.c
# [83/115] ChibiOS: Compiling chdynamic.c
# [84/115] ChibiOS: Compiling chevents.c
# [85/115] ChibiOS: Compiling chinstances.c
# [86/115] ChibiOS: Compiling chmsg.c
# [87/115] ChibiOS: Compiling chmtx.c
# [88/115] ChibiOS: Compiling chregistry.c
# [89/115] ChibiOS: Compiling chrfcu.c
# [90/115] ChibiOS: Compiling chschd.c
# [91/115] ChibiOS: Compiling chsem.c
# [92/115] ChibiOS: Compiling chstats.c
# [93/115] ChibiOS: Compiling chsys.c
# [94/115] ChibiOS: Compiling chthreads.c
# [95/115] ChibiOS: Compiling chtm.c
# [96/115] ChibiOS: Compiling chtrace.c
# [97/115] ChibiOS: Compiling chvt.c
# [98/115] ChibiOS: Compiling fatfs_diskio.c
# [99/115] ChibiOS: Compiling fatfs_syscall.c
# [100/115] ChibiOS: Compiling syscalls.c
# [101/115] ChibiOS: Compiling stubs.c
# [102/115] ChibiOS: Compiling board.c
# [103/115] ChibiOS: Compiling usbcfg.c
# [104/115] ChibiOS: Compiling usbcfg_dualcdc.c
# [105/115] ChibiOS: Compiling usbcfg_common.c
# [106/115] ChibiOS: Compiling flash.c
# [107/115] ChibiOS: Compiling malloc.c
# [108/115] ChibiOS: Compiling hrt.c
# [109/115] ChibiOS: Compiling stm32_util.c
# [110/115] ChibiOS: Compiling bouncebuffer.c
# [111/115] ChibiOS: Compiling watchdog.c
# [112/115] ChibiOS: Compiling ch.cpp
# [113/115] ChibiOS: Compiling CrashCatcher_armv7m.S
# [114/115] ChibiOS: Compiling CrashCatcher.c
# [115/115] ChibiOS: Compiling crashdump.c
#
# ChibiOS: Done!
#
# CrashCatcher: Done!
#
# arm-none-eabi-ar: creating modules/ChibiOS/libch.a
# arm-none-eabi-ar: creating modules/ChibiOS/libcc.a
#
# [  11/1016] Compiling libraries/AC_AttitudeControl/ControlMonitor.cpp
# [  12/1016] Compiling libraries/AC_AttitudeControl/AC_AttitudeControl_Multi_6DoF.cpp
# [  13/1016] Compiling libraries/AC_AttitudeControl/AC_AttitudeControl_Heli.cpp
# [  14/1016] Compiling libraries/AC_AttitudeControl/AC_CommandModel.cpp
# [  15/1016] Compiling libraries/AC_AttitudeControl/AC_AttitudeControl_Multi.cpp
# [  16/1016] Compiling libraries/AC_AttitudeControl/AC_AttitudeControl_TS.cpp
# [  17/1016] Compiling libraries/AC_AttitudeControl/AC_AttitudeControl_Sub.cpp
# [  18/1016] Compiling libraries/AC_AutoTune/AC_AutoTune_FreqResp.cpp
# [  19/1016] Compiling libraries/AC_AutoTune/AC_AutoTune_Heli.cpp
# [  20/1016] Compiling libraries/AC_AutoTune/AC_AutoTune_Multi.cpp
# [  21/1016] Compiling libraries/AC_Autorotation/AC_Autorotation.cpp
# [  22/1016] Compiling libraries/AC_Avoidance/AP_OAVisGraph.cpp
# [  23/1016] Compiling libraries/AC_Avoidance/AC_Avoidance_Logging.cpp
# [  24/1016] Compiling libraries/AC_Avoidance/AP_OADijkstra.cpp
# [  25/1016] Compiling libraries/AC_Avoidance/AP_OAPathPlanner.cpp
# [  26/1016] Compiling libraries/AC_InputManager/AC_InputManager_Heli.cpp
# [  27/1016] Compiling libraries/AC_InputManager/AC_InputManager.cpp
# [  28/1016] Compiling libraries/AC_PID/AC_PI_2D.cpp
# [  29/1016] Compiling libraries/AC_PID/AC_PID.cpp
# [  30/1016] Compiling libraries/AC_PID/AC_P.cpp
# [  31/1016] Compiling libraries/AC_PID/AC_HELI_PID.cpp
# [  32/1016] Compiling libraries/AC_PID/AC_P_1D.cpp
# [  33/1016] Compiling libraries/AC_PID/AC_P_2D.cpp
# [  34/1016] Compiling libraries/AC_PID/AC_PI.cpp
# [  35/1016] Compiling libraries/AC_PID/AC_PID_Basic.cpp
# [  36/1016] Compiling libraries/AC_PID/AC_PID_2D.cpp
# [  37/1016] Compiling libraries/AC_PrecLand/AC_PrecLand_StateMachine.cpp
# [  38/1016] Compiling libraries/AC_PrecLand/AC_PrecLand_SITL.cpp
# [  39/1016] Compiling libraries/AC_PrecLand/AC_PrecLand_SITL_Gazebo.cpp
# [  40/1016] Compiling libraries/AC_PrecLand/AC_PrecLand_IRLock.cpp
# [  41/1016] Compiling libraries/AC_PrecLand/AC_PrecLand_Companion.cpp
# [  42/1016] Compiling libraries/AC_PrecLand/PosVelEKF.cpp
# [  43/1016] Compiling libraries/AC_Sprayer/AC_Sprayer.cpp
# [  44/1016] Compiling libraries/AC_WPNav/AC_WPNav_OA.cpp
# [  45/1016] Compiling libraries/AC_WPNav/AC_Circle.cpp
# [  46/1016] Compiling libraries/AC_WPNav/AC_WPNav.cpp
# [  47/1016] Compiling libraries/AP_ADC/AP_ADC_ADS1115.cpp
# [  48/1016] Compiling libraries/AP_ADSB/AP_ADSB_Backend.cpp
# [  49/1016] Compiling libraries/AP_ADSB/AP_ADSB_uAvionix_MAVLink.cpp
# [  50/1016] Compiling libraries/AP_ADSB/AP_ADSB_uAvionix_UCP.cpp
# [  51/1016] Compiling libraries/AP_ADSB/AP_ADSB_Sagetech.cpp
# [  52/1016] Compiling libraries/AP_AHRS/AP_AHRS_SIM.cpp
# [  53/1016] Compiling libraries/AP_AHRS/AP_AHRS_View.cpp
# [  54/1016] Compiling libraries/AP_AHRS/AP_AHRS_Logging.cpp
# [  55/1016] Compiling libraries/AP_AccelCal/AccelCalibrator.cpp
# [  56/1016] Compiling libraries/AP_AccelCal/AP_AccelCal.cpp
# [  57/1016] Compiling libraries/AP_AdvancedFailsafe/AP_AdvancedFailsafe.cpp
# [  58/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_SITL.cpp
# [  59/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_MSP.cpp
# [  60/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_Health.cpp
# [  61/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_DroneCAN.cpp
# [  62/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_DLVR.cpp
# [  63/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_Backend.cpp
# [  64/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_ASP5033.cpp
# [  65/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_analog.cpp
# [  66/1016] Compiling libraries/AP_Airspeed/Airspeed_Calibration.cpp
# [  67/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_MS4525.cpp
# [  68/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_SDP3X.cpp
# [  69/1016] Compiling libraries/AP_Airspeed/AP_Airspeed_MS5525.cpp
# [  70/1016] Compiling libraries/AP_Baro/AP_Baro_Backend.cpp
# [  71/1016] Compiling libraries/AP_Baro/AP_Baro_BMP280.cpp
# [  72/1016] Compiling libraries/AP_Baro/AP_Baro_MS5611.cpp
# [  73/1016] Compiling libraries/AP_Baro/AP_Baro_Logging.cpp
# [  74/1016] Compiling libraries/AP_Baro/AP_Baro_LPS2XH.cpp
# [  75/1016] Compiling libraries/AP_Baro/AP_Baro_KellerLD.cpp
# [  76/1016] Compiling libraries/AP_Baro/AP_Baro_ICP201XX.cpp
# [  77/1016] Compiling libraries/AP_Baro/AP_Baro_ICP101XX.cpp
# [  78/1016] Compiling libraries/AP_Baro/AP_Baro_ICM20789.cpp
# [  79/1016] Compiling libraries/AP_Baro/AP_Baro_HIL.cpp
# [  80/1016] Compiling libraries/AP_Baro/AP_Baro_FBM320.cpp
# [  81/1016] Compiling libraries/AP_Baro/AP_Baro_ExternalAHRS.cpp
# [  82/1016] Compiling libraries/AP_Baro/AP_Baro_Dummy.cpp
# [  83/1016] Compiling libraries/AP_Baro/AP_Baro_DroneCAN.cpp
# [  84/1016] Compiling libraries/AP_Baro/AP_Baro_DPS280.cpp
# [  85/1016] Compiling libraries/AP_Baro/AP_Baro_BMP388.cpp
# [  86/1016] Compiling libraries/AP_Baro/AP_Baro_BMP085.cpp
# [  87/1016] Compiling libraries/AP_Baro/AP_Baro_MSP.cpp
# [  88/1016] Compiling libraries/AP_Baro/AP_Baro_Wind.cpp
# [  89/1016] Compiling libraries/AP_Baro/AP_Baro_SPL06.cpp
# [  90/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_Torqeedo.cpp
# [  91/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_Sum.cpp
# [  92/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_SMBus_Generic.cpp
# [  93/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_SMBus.cpp
# [  94/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_Logging.cpp
# [  95/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_LTC2946.cpp
# [  96/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_INA2xx.cpp
# [  97/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_INA239.cpp
# [  98/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_Generator.cpp
# [  99/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_FuelLevel_PWM.cpp
# [ 100/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_FuelLevel_Analog.cpp
# [ 101/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_FuelFlow.cpp
# [ 102/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_ESC.cpp
# [ 103/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_EFI.cpp
# [ 104/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_DroneCAN.cpp
# [ 105/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_Bebop.cpp
# [ 106/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_Backend.cpp
# [ 107/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_Analog.cpp
# [ 108/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_Synthetic_Current.cpp
# [ 109/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_SMBus_Solo.cpp
# [ 110/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_SMBus_NeoDesign.cpp
# [ 111/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_SMBus_SUI.cpp
# [ 112/1016] Compiling libraries/AP_BattMonitor/AP_BattMonitor_SMBus_Rotoye.cpp
# [ 113/1016] Compiling libraries/AP_Beacon/AP_Beacon_SITL.cpp
# [ 114/1016] Compiling libraries/AP_Beacon/AP_Beacon_Nooploop.cpp
# [ 115/1016] Compiling libraries/AP_Beacon/AP_Beacon_Pozyx.cpp
# [ 116/1016] Compiling libraries/AP_Beacon/AP_Beacon_Marvelmind.cpp
# [ 117/1016] Compiling libraries/AP_Beacon/AP_Beacon_Backend.cpp
# [ 118/1016] Compiling libraries/AP_Beacon/AP_Beacon.cpp
# [ 119/1016] Compiling libraries/AP_BoardConfig/IMU_heater.cpp
# [ 120/1016] Compiling libraries/AP_BoardConfig/board_drivers.cpp
# [ 121/1016] Compiling libraries/AP_Button/AP_Button.cpp
# [ 122/1016] Compiling libraries/AP_CANManager/AP_SLCANIface.cpp
# [ 123/1016] Compiling libraries/AP_CANManager/AP_CANDriver.cpp
# [ 124/1016] Compiling libraries/AP_CANManager/AP_CANIfaceParams.cpp
# [ 125/1016] Compiling libraries/AP_CANManager/AP_CANSensor.cpp
# [ 126/1016] Compiling libraries/AP_CANManager/AP_CANManager.cpp
# [ 127/1016] Compiling libraries/AP_Camera/AP_Camera_Servo.cpp
# [ 128/1016] Compiling libraries/AP_Camera/AP_Camera_Relay.cpp
# [ 129/1016] Compiling libraries/AP_Camera/AP_Camera_MAVLink.cpp
# [ 130/1016] Compiling libraries/AP_Camera/AP_Camera_Logging.cpp
# [ 131/1016] Compiling libraries/AP_Camera/AP_Camera_Backend.cpp
# [ 132/1016] Compiling libraries/AP_Camera/AP_Camera.cpp
# [ 133/1016] Compiling libraries/AP_Camera/AP_RunCam.cpp
# [ 134/1016] Compiling libraries/AP_Camera/AP_Camera_Scripting.cpp
# [ 135/1016] Compiling libraries/AP_Camera/AP_Camera_SoloGimbal.cpp
# [ 136/1016] Compiling libraries/AP_Camera/AP_Camera_MAVLinkCamV2.cpp
# [ 137/1016] Compiling libraries/AP_Camera/AP_Camera_Params.cpp
# [ 138/1016] Compiling libraries/AP_Camera/AP_Camera_Mount.cpp
# [ 139/1016] Compiling libraries/AP_CheckFirmware/monocypher.cpp
# [ 140/1016] Compiling libraries/AP_CheckFirmware/AP_CheckFirmware.cpp
# [ 141/1016] Compiling libraries/AP_CheckFirmware/AP_CheckFirmware_secure_command.cpp
# [ 142/1016] Compiling libraries/AP_Common/MultiHeap.cpp
# [ 143/1016] Compiling libraries/AP_Common/ExpandingString.cpp
# [ 144/1016] Compiling libraries/AP_Common/AP_FWVersion.cpp
# [ 145/1016] Compiling libraries/AP_Common/AP_ExpandingArray.cpp
# [ 146/1016] Compiling libraries/AP_Common/AP_Common.cpp
# [ 147/1016] Compiling libraries/AP_Common/Location.cpp
# [ 148/1016] Compiling libraries/AP_Common/sorting.cpp
# [ 149/1016] Compiling libraries/AP_Common/NMEA.cpp
# [ 150/1016] Compiling libraries/AP_Common/float16.cpp
# [ 151/1016] Compiling libraries/AP_Common/c++.cpp
# [ 152/1016] Compiling libraries/AP_Compass/Compass_learn.cpp
# [ 153/1016] Compiling libraries/AP_Compass/CompassCalibrator.cpp
# [ 154/1016] Compiling libraries/AP_Compass/AP_Compass_MMC5xx3.cpp
# [ 155/1016] Compiling libraries/AP_Compass/AP_Compass_MMC3416.cpp
# [ 156/1016] Compiling libraries/AP_Compass/AP_Compass_MAG3110.cpp
# [ 157/1016] Compiling libraries/AP_Compass/AP_Compass_LSM9DS1.cpp
# [ 158/1016] Compiling libraries/AP_Compass/AP_Compass_LSM303D.cpp
# [ 159/1016] Compiling libraries/AP_Compass/AP_Compass_LIS3MDL.cpp
# [ 160/1016] Compiling libraries/AP_Compass/AP_Compass_IST8310.cpp
# [ 161/1016] Compiling libraries/AP_Compass/AP_Compass_IST8308.cpp
# [ 162/1016] Compiling libraries/AP_Compass/AP_Compass_HMC5843.cpp
# [ 163/1016] Compiling libraries/AP_Compass/AP_Compass_ExternalAHRS.cpp
# [ 164/1016] Compiling libraries/AP_Compass/AP_Compass_DroneCAN.cpp
# [ 165/1016] Compiling libraries/AP_Compass/AP_Compass_Calibration.cpp
# [ 166/1016] Compiling libraries/AP_Compass/AP_Compass_Backend.cpp
# [ 167/1016] Compiling libraries/AP_Compass/AP_Compass_BMM150.cpp
# [ 168/1016] Compiling libraries/AP_Compass/AP_Compass_AK8963.cpp
# [ 169/1016] Compiling libraries/AP_Compass/AP_Compass_AK09916.cpp
# [ 170/1016] Compiling libraries/AP_Compass/Compass_PerMotor.cpp
# [ 171/1016] Compiling libraries/AP_Compass/AP_Compass_SITL.cpp
# [ 172/1016] Compiling libraries/AP_Compass/AP_Compass_MSP.cpp
# [ 173/1016] Compiling libraries/AP_Compass/AP_Compass_RM3100.cpp
# [ 174/1016] Compiling libraries/AP_Compass/AP_Compass_QMC5883L.cpp
# [ 175/1016] Compiling libraries/AP_DAL/AP_DAL_InertialSensor.cpp
# [ 176/1016] Compiling libraries/AP_DAL/AP_DAL_Compass.cpp
# [ 177/1016] Compiling libraries/AP_DAL/AP_DAL_GPS.cpp
# [ 178/1016] Compiling libraries/AP_DAL/AP_DAL_Baro.cpp
# [ 179/1016] Compiling libraries/AP_DAL/AP_DAL_Airspeed.cpp
# [ 180/1016] Compiling libraries/AP_Declination/AP_Declination.cpp
# [ 181/1016] Compiling libraries/AP_Declination/tables.cpp
# [ 182/1016] Compiling libraries/AP_Devo_Telem/AP_Devo_Telem.cpp
# [ 183/1016] Compiling libraries/AP_DroneCAN/AP_DroneCAN.cpp
# [ 184/1016] Compiling libraries/AP_DroneCAN/AP_DroneCAN_DNA_Server.cpp
# [ 185/1016] Compiling libraries/AP_DroneCAN/AP_Canard_iface.cpp
# [ 186/1016] Compiling libraries/AP_EFI/AP_EFI_NWPMU.cpp
# [ 187/1016] Compiling libraries/AP_EFI/AP_EFI_Currawong_ECU.cpp
# [ 188/1016] Compiling libraries/AP_EFI/AP_EFI.cpp
# [ 189/1016] Compiling libraries/AP_EFI/AP_EFI_DroneCAN.cpp
# [ 190/1016] Compiling libraries/AP_EFI/AP_EFI_Serial_MS.cpp
# [ 191/1016] Compiling libraries/AP_EFI/AP_EFI_Backend.cpp
# [ 192/1016] Compiling libraries/AP_EFI/AP_EFI_Serial_Lutan.cpp
# [ 193/1016] Compiling libraries/AP_EFI/AP_EFI_Scripting.cpp
# [ 194/1016] Compiling libraries/AP_ESC_Telem/AP_ESC_Telem_Backend.cpp
# [ 195/1016] Compiling libraries/AP_ESC_Telem/AP_ESC_Telem.cpp
# [ 196/1016] Compiling libraries/AP_ESC_Telem/AP_ESC_Telem_SITL.cpp
# [ 197/1016] Compiling libraries/AP_ExternalAHRS/AP_ExternalAHRS_backend.cpp
# [ 198/1016] Compiling libraries/AP_ExternalAHRS/AP_ExternalAHRS.cpp
# [ 199/1016] Compiling libraries/AP_ExternalAHRS/AP_ExternalAHRS_VectorNav.cpp
# [ 200/1016] Compiling libraries/AP_ExternalAHRS/AP_ExternalAHRS_LORD.cpp
# [ 201/1016] Compiling libraries/AP_FETtecOneWire/AP_FETtecOneWire.cpp
# [ 202/1016] Compiling libraries/AP_Filesystem/AP_Filesystem_backend.cpp
# [ 203/1016] Compiling libraries/AP_Filesystem/AP_Filesystem_FATFS.cpp
# [ 204/1016] Compiling libraries/AP_Filesystem/AP_Filesystem_ESP32.cpp
# [ 205/1016] Compiling libraries/AP_Filesystem/AP_Filesystem.cpp
# [ 206/1016] Compiling libraries/AP_Filesystem/posix_compat.cpp
# [ 207/1016] Compiling libraries/AP_Filesystem/AP_Filesystem_Sys.cpp
# [ 208/1016] Compiling libraries/AP_Filesystem/AP_Filesystem_Mission.cpp
# [ 209/1016] Compiling libraries/AP_Filesystem/AP_Filesystem_ROMFS.cpp
# [ 210/1016] Compiling libraries/AP_Filesystem/AP_Filesystem_Param.cpp
# [ 211/1016] Compiling libraries/AP_FlashStorage/AP_FlashStorage.cpp
# [ 212/1016] Compiling libraries/AP_Frsky_Telem/AP_Frsky_SPort.cpp
# [ 213/1016] Compiling libraries/AP_Frsky_Telem/AP_Frsky_MAVliteMsgHandler.cpp
# [ 214/1016] Compiling libraries/AP_Frsky_Telem/AP_Frsky_D.cpp
# [ 215/1016] Compiling libraries/AP_Frsky_Telem/AP_Frsky_Backend.cpp
# [ 216/1016] Compiling libraries/AP_Frsky_Telem/AP_Frsky_Telem.cpp
# [ 217/1016] Compiling libraries/AP_Frsky_Telem/AP_Frsky_Parameters.cpp
# [ 218/1016] Compiling libraries/AP_Frsky_Telem/AP_Frsky_MAVlite_MAVliteToSPort.cpp
# [ 219/1016] Compiling libraries/AP_Frsky_Telem/AP_Frsky_MAVlite_SPortToMAVlite.cpp
# [ 220/1016] Compiling libraries/AP_Frsky_Telem/AP_Frsky_MAVlite_Message.cpp
# [ 221/1016] Compiling libraries/AP_GPS/RTCM3_Parser.cpp
# [ 222/1016] Compiling libraries/AP_GPS/GPS_Backend.cpp
# [ 223/1016] Compiling libraries/AP_GPS/AP_GPS_SBP.cpp
# [ 224/1016] Compiling libraries/AP_GPS/AP_GPS_SBF.cpp
# [ 225/1016] Compiling libraries/AP_GPS/AP_GPS_NOVA.cpp
# [ 226/1016] Compiling libraries/AP_GPS/AP_GPS_NMEA.cpp
# [ 227/1016] Compiling libraries/AP_GPS/AP_GPS_MSP.cpp
# [ 228/1016] Compiling libraries/AP_GPS/AP_GPS_MAV.cpp
# [ 229/1016] Compiling libraries/AP_GPS/AP_GPS_GSOF.cpp
# [ 230/1016] Compiling libraries/AP_GPS/AP_GPS_ExternalAHRS.cpp
# [ 231/1016] Compiling libraries/AP_GPS/AP_GPS_ERB.cpp
# [ 232/1016] Compiling libraries/AP_GPS/AP_GPS_DroneCAN.cpp
# [ 233/1016] Compiling libraries/AP_GPS/AP_GPS.cpp
# [ 234/1016] Compiling libraries/AP_GPS/MovingBase.cpp
# [ 235/1016] Compiling libraries/AP_GPS/AP_GPS_UBLOX.cpp
# [ 236/1016] Compiling libraries/AP_GPS/AP_GPS_SBP2.cpp
# [ 237/1016] Compiling libraries/AP_GPS/AP_GPS_SITL.cpp
# [ 238/1016] Compiling libraries/AP_GPS/AP_GPS_SIRF.cpp
# [ 239/1016] Compiling libraries/AP_Generator/AP_Generator_RichenPower.cpp
# [ 240/1016] Compiling libraries/AP_Generator/AP_Generator_IE_650_800.cpp
# [ 241/1016] Compiling libraries/AP_Generator/AP_Generator_IE_FuelCell.cpp
# [ 242/1016] Compiling libraries/AP_Generator/AP_Generator_IE_2400.cpp
# [ 243/1016] Compiling libraries/AP_Generator/AP_Generator_Backend.cpp
# [ 244/1016] Compiling libraries/AP_Generator/AP_Generator.cpp
# [ 245/1016] Compiling libraries/AP_Gripper/AP_Gripper_EPM.cpp
# [ 246/1016] Compiling libraries/AP_Gripper/AP_Gripper.cpp
# [ 247/1016] Compiling libraries/AP_Gripper/AP_Gripper_Backend.cpp
# [ 248/1016] Compiling libraries/AP_Gripper/AP_Gripper_Servo.cpp
# [ 249/1016] Compiling libraries/AP_Hott_Telem/AP_Hott_Telem.cpp
# [ 250/1016] Compiling libraries/AP_ICEngine/AP_ICEngine.cpp
# [ 251/1016] Compiling libraries/AP_IOMCU/AP_IOMCU.cpp
# [ 252/1016] Compiling libraries/AP_IOMCU/fw_uploader.cpp
# [ 253/1016] Compiling libraries/AP_IRLock/AP_IRLock_SITL_Gazebo.cpp
# [ 254/1016] Compiling libraries/AP_IRLock/IRLock.cpp
# [ 255/1016] Compiling libraries/AP_IRLock/AP_IRLock_SITL.cpp
# [ 256/1016] Compiling libraries/AP_IRLock/AP_IRLock_I2C.cpp
# [ 257/1016] Compiling libraries/AP_InertialNav/AP_InertialNav.cpp
# [ 258/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_Invensense.cpp
# [ 259/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_BMI270.cpp
# [ 260/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_ADIS1647x.cpp
# [ 261/1016] Compiling libraries/AP_InertialSensor/BatchSampler.cpp
# [ 262/1016] Compiling libraries/AP_InertialSensor/AuxiliaryBus.cpp
# [ 263/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_tempcal.cpp
# [ 264/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_SITL.cpp
# [ 265/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_SCHA63T.cpp
# [ 266/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_RST.cpp
# [ 267/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_Params.cpp
# [ 268/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_NONE.cpp
# [ 269/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_Logging.cpp
# [ 270/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_LSM9DS1.cpp
# [ 271/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_LSM9DS0.cpp
# [ 272/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_L3G4200D.cpp
# [ 273/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_Invensensev3.cpp
# [ 274/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_Invensensev2.cpp
# [ 275/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_Backend.cpp
# [ 276/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_BMI088.cpp
# [ 277/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_BMI055.cpp
# [ 278/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_ExternalAHRS.cpp
# [ 279/1016] Compiling libraries/AP_InertialSensor/AP_InertialSensor_BMI160.cpp
# [ 280/1016] Compiling libraries/AP_InternalError/AP_InternalError.cpp
# [ 281/1016] Compiling libraries/AP_KDECAN/AP_KDECAN.cpp
# [ 282/1016] Compiling libraries/AP_LTM_Telem/AP_LTM_Telem.cpp
# [ 283/1016] Compiling libraries/AP_Logger/AP_Logger_Block.cpp
# [ 284/1016] Compiling libraries/AP_Logger/AP_Logger_DataFlash.cpp
# [ 285/1016] Compiling libraries/AP_Logger/LogFile.cpp
# [ 286/1016] Compiling libraries/AP_Logger/AP_Logger_MAVLink.cpp
# [ 287/1016] Compiling libraries/AP_Logger/AP_Logger_W25N01GV.cpp
# [ 288/1016] Compiling libraries/AP_Logger/AP_Logger_MAVLinkLogTransfer.cpp
# [ 289/1016] Compiling libraries/AP_MSP/msp_sbuf.cpp
# [ 290/1016] Compiling libraries/AP_MSP/AP_MSP_Telem_Generic.cpp
# [ 291/1016] Compiling libraries/AP_MSP/msp.cpp
# [ 292/1016] Compiling libraries/AP_MSP/AP_MSP_Telem_DisplayPort.cpp
# [ 293/1016] Compiling libraries/AP_MSP/AP_MSP.cpp
# [ 294/1016] Compiling libraries/AP_MSP/AP_MSP_Telem_DJI.cpp
# [ 295/1016] Compiling libraries/AP_MSP/AP_MSP_Telem_Backend.cpp
# [ 296/1016] Compiling libraries/AP_Math/vector2.cpp
# [ 297/1016] Compiling libraries/AP_Math/polygon.cpp
# [ 298/1016] Compiling libraries/AP_Math/location_double.cpp
# [ 299/1016] Compiling libraries/AP_Math/location.cpp
# [ 300/1016] Compiling libraries/AP_Math/crc.cpp
# [ 301/1016] Compiling libraries/AP_Math/control.cpp
# [ 302/1016] Compiling libraries/AP_Math/chirp.cpp
# [ 303/1016] Compiling libraries/AP_Math/SplineCurve.cpp
# [ 304/1016] Compiling libraries/AP_Math/AP_Math.cpp
# [ 305/1016] Compiling libraries/AP_Math/matrixN.cpp
# [ 306/1016] Compiling libraries/AP_Math/AP_GeodesicGrid.cpp
# [ 307/1016] Compiling libraries/AP_Math/spline5.cpp
# [ 308/1016] Compiling libraries/AP_Math/polyfit.cpp
# [ 309/1016] Compiling libraries/AP_Math/matrix3.cpp
# [ 310/1016] Compiling libraries/AP_Math/matrix_alg.cpp
# [ 311/1016] Compiling libraries/AP_Mission/AP_Mission_ChangeDetector.cpp
# [ 312/1016] Compiling libraries/AP_Mission/AP_Mission_Commands.cpp
# [ 313/1016] Compiling libraries/AP_Module/AP_Module.cpp
# [ 314/1016] Compiling libraries/AP_Motors/AP_Motors_Class.cpp
# [ 315/1016] Compiling libraries/AP_Motors/AP_MotorsHeli_Single.cpp
# [ 316/1016] Compiling libraries/AP_Motors/AP_MotorsHeli_RSC.cpp
# [ 317/1016] Compiling libraries/AP_Motors/AP_MotorsHeli_Quad.cpp
# [ 318/1016] Compiling libraries/AP_Motors/AP_MotorsHeli_Dual.cpp
# [ 319/1016] Compiling libraries/AP_Motors/AP_MotorsHeli.cpp
# [ 320/1016] Compiling libraries/AP_Motors/AP_MotorsCoax.cpp
# [ 321/1016] Compiling libraries/AP_Motors/AP_Motors6DOF.cpp
# [ 322/1016] Compiling libraries/AP_Motors/AP_MotorsMatrix_6DoF_Scripting.cpp
# [ 323/1016] Compiling libraries/AP_Motors/AP_MotorsTailsitter.cpp
# [ 324/1016] Compiling libraries/AP_Motors/AP_MotorsHeli_Swash.cpp
# [ 325/1016] Compiling libraries/AP_Motors/AP_MotorsSingle.cpp
# [ 326/1016] Compiling libraries/AP_Motors/AP_MotorsMatrix_Scripting_Dynamic.cpp
# [ 327/1016] Compiling libraries/AP_Mount/SoloGimbal_Parameters.cpp
# [ 328/1016] Compiling libraries/AP_Mount/SoloGimbal.cpp
# [ 329/1016] Compiling libraries/AP_Mount/AP_Mount_SToRM32_serial.cpp
# [ 330/1016] Compiling libraries/AP_Mount/AP_Mount_SToRM32.cpp
# [ 331/1016] Compiling libraries/AP_Mount/AP_Mount_Params.cpp
# [ 332/1016] Compiling libraries/AP_Mount/AP_Mount_Gremsy.cpp
# [ 333/1016] Compiling libraries/AP_Mount/AP_Mount_Backend.cpp
# [ 334/1016] Compiling libraries/AP_Mount/AP_Mount_Alexmos.cpp
# [ 335/1016] Compiling libraries/AP_Mount/AP_Mount.cpp
# [ 336/1016] Compiling libraries/AP_Mount/SoloGimbalEKF.cpp
# [ 337/1016] Compiling libraries/AP_Mount/AP_Mount_Servo.cpp
# [ 338/1016] Compiling libraries/AP_Mount/AP_Mount_SoloGimbal.cpp
# [ 339/1016] Compiling libraries/AP_Mount/AP_Mount_Scripting.cpp
# [ 340/1016] Compiling libraries/AP_Mount/AP_Mount_Siyi.cpp
# [ 341/1016] Compiling libraries/AP_NMEA_Output/AP_NMEA_Output.cpp
# [ 342/1016] Compiling libraries/AP_NavEKF/EKFGSF_Logging.cpp
# [ 343/1016] Compiling libraries/AP_NavEKF/EKF_Buffer.cpp
# [ 344/1016] Compiling libraries/AP_NavEKF/AP_NavEKF_core_common.cpp
# [ 345/1016] Compiling libraries/AP_NavEKF/AP_NavEKF_Source.cpp
# [ 346/1016] Compiling libraries/AP_NavEKF/EKFGSF_yaw.cpp
# [ 347/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF2_core.cpp
# [ 348/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF2_RngBcnFusion.cpp
# [ 349/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF2_MagFusion.cpp
# [ 350/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF2_Logging.cpp
# [ 351/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF2_Control.cpp
# [ 352/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF2_AirDataFusion.cpp
# [ 353/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF2_VehicleStatus.cpp
# [ 354/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF2_PosVelFusion.cpp
# [ 355/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF2_Measurements.cpp
# [ 356/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF_GyroBias.cpp
# [ 357/1016] Compiling libraries/AP_NavEKF2/AP_NavEKF2_Outputs.cpp
# [ 358/1016] Compiling libraries/AP_Notify/VRBoard_LED.cpp
# [ 359/1016] Compiling libraries/AP_Notify/ToneAlarm.cpp
# [ 360/1016] Compiling libraries/AP_Notify/RCOutputRGBLed.cpp
# [ 361/1016] Compiling libraries/AP_Notify/ProfiLED.cpp
# [ 362/1016] Compiling libraries/AP_Notify/PixRacerLED.cpp
# [ 363/1016] Compiling libraries/AP_Notify/PCA9685LED_I2C.cpp
# [ 364/1016] Compiling libraries/AP_Notify/OreoLED_I2C.cpp
# [ 365/1016] Compiling libraries/AP_Notify/NeoPixel.cpp
# [ 366/1016] Compiling libraries/AP_Notify/NavigatorLED.cpp
# [ 367/1016] Compiling libraries/AP_Notify/NCP5623.cpp
# [ 368/1016] Compiling libraries/AP_Notify/MMLPlayer.cpp
# [ 369/1016] Compiling libraries/AP_Notify/Led_Sysfs.cpp
# [ 370/1016] Compiling libraries/AP_Notify/LP5562.cpp
# [ 371/1016] Compiling libraries/AP_Notify/ExternalLED.cpp
# [ 372/1016] Compiling libraries/AP_Notify/DroneCAN_RGB_LED.cpp
# [ 373/1016] Compiling libraries/AP_Notify/Display_SSD1306_I2C.cpp
# [ 374/1016] Compiling libraries/AP_Notify/Display_SITL.cpp
# [ 375/1016] Compiling libraries/AP_Notify/Display_SH1106_I2C.cpp
# [ 376/1016] Compiling libraries/AP_Notify/Display.cpp
# [ 377/1016] Compiling libraries/AP_Notify/DiscreteRGBLed.cpp
# [ 378/1016] Compiling libraries/AP_Notify/DiscoLED.cpp
# [ 379/1016] Compiling libraries/AP_Notify/DShotLED.cpp
# [ 380/1016] Compiling libraries/AP_Notify/SITL_SFML_LED.cpp
# [ 381/1016] Compiling libraries/AP_Notify/AP_Notify.cpp
# [ 382/1016] Compiling libraries/AP_Notify/AP_BoardLED2.cpp
# [ 383/1016] Compiling libraries/AP_Notify/AP_BoardLED.cpp
# [ 384/1016] Compiling libraries/AP_Notify/ToshibaLED_I2C.cpp
# [ 385/1016] Compiling libraries/AP_Notify/SerialLED.cpp
# [ 386/1016] Compiling libraries/AP_Notify/RGBLed.cpp
# [ 387/1016] Compiling libraries/AP_Notify/ScriptingLED.cpp
# [ 388/1016] Compiling libraries/AP_Notify/Buzzer.cpp
# [ 389/1016] Compiling libraries/AP_OLC/AP_OLC.cpp
# [ 390/1016] Compiling libraries/AP_OSD/AP_OSD_SITL.cpp
# [ 391/1016] Compiling libraries/AP_OSD/AP_OSD.cpp
# [ 392/1016] Compiling libraries/AP_OSD/AP_OSD_Setting.cpp
# [ 393/1016] Compiling libraries/AP_OSD/AP_OSD_MSP_DisplayPort.cpp
# [ 394/1016] Compiling libraries/AP_OSD/AP_OSD_Backend.cpp
# [ 395/1016] Compiling libraries/AP_OSD/AP_OSD_MSP.cpp
# [ 396/1016] Compiling libraries/AP_OSD/AP_OSD_MAX7456.cpp
# [ 397/1016] Compiling libraries/AP_OpenDroneID/AP_OpenDroneID_DroneCAN.cpp
# [ 398/1016] Compiling libraries/AP_OpenDroneID/AP_OpenDroneID.cpp
# [ 399/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_UPFLOW.cpp
# [ 400/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_MAV.cpp
# [ 401/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_HereFlow.cpp
# [ 402/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_Calibrator.cpp
# [ 403/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_CXOF.cpp
# [ 404/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_Backend.cpp
# [ 405/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow.cpp
# [ 406/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_MSP.cpp
# [ 407/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_SITL.cpp
# [ 408/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_Onboard.cpp
# [ 409/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_Pixart.cpp
# [ 410/1016] Compiling libraries/AP_OpticalFlow/AP_OpticalFlow_PX4Flow.cpp
# [ 411/1016] Compiling libraries/AP_Parachute/AP_Parachute.cpp
# [ 412/1016] Compiling libraries/AP_Param/AP_Param.cpp
# [ 413/1016] Compiling libraries/AP_Param/AP_ParamT.cpp
# [ 414/1016] Compiling libraries/AP_PiccoloCAN/AP_PiccoloCAN.cpp
# [ 415/1016] Compiling libraries/AP_Proximity/AP_Proximity_RangeFinder.cpp
# [ 416/1016] Compiling libraries/AP_Proximity/AP_Proximity_Params.cpp
# [ 417/1016] Compiling libraries/AP_Proximity/AP_Proximity_LightWareSerial.cpp
# [ 418/1016] Compiling libraries/AP_Proximity/AP_Proximity_LightWareSF45B.cpp
# [ 419/1016] Compiling libraries/AP_Proximity/AP_Proximity_LightWareSF40C.cpp
# [ 420/1016] Compiling libraries/AP_Proximity/AP_Proximity_DroneCAN.cpp
# [ 421/1016] Compiling libraries/AP_Proximity/AP_Proximity_Cygbot_D1.cpp
# [ 422/1016] Compiling libraries/AP_Proximity/AP_Proximity_Boundary_3D.cpp
# [ 423/1016] Compiling libraries/AP_Proximity/AP_Proximity_Backend_Serial.cpp
# [ 424/1016] Compiling libraries/AP_Proximity/AP_Proximity_AirSimSITL.cpp
# [ 425/1016] Compiling libraries/AP_Proximity/AP_Proximity.cpp
# [ 426/1016] Compiling libraries/AP_Proximity/AP_Proximity_RPLidarA2.cpp
# [ 427/1016] Compiling libraries/AP_Proximity/AP_Proximity_SITL.cpp
# [ 428/1016] Compiling libraries/AP_Proximity/AP_Proximity_MAV.cpp
# [ 429/1016] Compiling libraries/AP_Proximity/AP_Proximity_TeraRangerTowerEvo.cpp
# [ 430/1016] Compiling libraries/AP_Proximity/AP_Proximity_TeraRangerTower.cpp
# [ 431/1016] Compiling libraries/AP_RAMTRON/AP_RAMTRON.cpp
# [ 432/1016] Compiling libraries/AP_RCMapper/AP_RCMapper.cpp
# [ 433/1016] Compiling libraries/AP_RCProtocol/spm_srxl.cpp
# [ 434/1016] Compiling libraries/AP_RCProtocol/AP_RCProtocol_PPMSum.cpp
# [ 435/1016] Compiling libraries/AP_RCProtocol/AP_RCProtocol_IBUS.cpp
# [ 436/1016] Compiling libraries/AP_RCProtocol/AP_RCProtocol_DSM.cpp
# [ 437/1016] Compiling libraries/AP_RCProtocol/AP_RCProtocol_Backend.cpp
# [ 438/1016] Compiling libraries/AP_RCProtocol/AP_RCProtocol_SBUS.cpp
# [ 439/1016] Compiling libraries/AP_RCProtocol/SoftSerial.cpp
# [ 440/1016] Compiling libraries/AP_RCProtocol/AP_RCProtocol_SRXL.cpp
# [ 441/1016] Compiling libraries/AP_RCProtocol/AP_RCProtocol_SUMD.cpp
# [ 442/1016] Compiling libraries/AP_RCProtocol/AP_RCProtocol_ST24.cpp
# [ 443/1016] Compiling libraries/AP_RCTelemetry/AP_Spektrum_Telem.cpp
# [ 444/1016] Compiling libraries/AP_ROMFS/tinfgzip.cpp
# [ 445/1016] Compiling libraries/AP_ROMFS/tinflate.cpp
# [ 446/1016] Compiling libraries/AP_ROMFS/AP_ROMFS.cpp
# [ 447/1016] Compiling libraries/AP_RPM/RPM_Generator.cpp
# [ 448/1016] Compiling libraries/AP_RPM/RPM_EFI.cpp
# [ 449/1016] Compiling libraries/AP_RPM/AP_RPM_Params.cpp
# [ 450/1016] Compiling libraries/AP_RPM/AP_RPM.cpp
# [ 451/1016] Compiling libraries/AP_RPM/RPM_ESC_Telem.cpp
# [ 452/1016] Compiling libraries/AP_RPM/RPM_Pin.cpp
# [ 453/1016] Compiling libraries/AP_RPM/RPM_HarmonicNotch.cpp
# [ 454/1016] Compiling libraries/AP_RPM/RPM_Backend.cpp
# [ 455/1016] Compiling libraries/AP_RPM/RPM_SITL.cpp
# [ 456/1016] Compiling libraries/AP_RSSI/AP_RSSI.cpp
# [ 457/1016] Compiling libraries/AP_RTC/AP_RTC.cpp
# [ 458/1016] Compiling libraries/AP_RTC/JitterCorrection.cpp
# [ 459/1016] Compiling libraries/AP_Radio/driver_cc2500.cpp
# [ 460/1016] Compiling libraries/AP_Radio/AP_Radio_backend.cpp
# [ 461/1016] Compiling libraries/AP_Radio/AP_Radio_bk2425.cpp
# [ 462/1016] Compiling libraries/AP_Radio/driver_bk2425.cpp
# [ 463/1016] Compiling libraries/AP_Radio/AP_Radio.cpp
# [ 464/1016] Compiling libraries/AP_Radio/AP_Radio_cypress.cpp
# [ 465/1016] Compiling libraries/AP_Radio/AP_Radio_cc2500.cpp
# [ 466/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_analog.cpp
# [ 467/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_VL53L1X.cpp
# [ 468/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_TeraRangerI2C.cpp
# [ 469/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_SITL.cpp
# [ 470/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_PulsedLightLRF.cpp
# [ 471/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_Params.cpp
# [ 472/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_PWM.cpp
# [ 473/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_NMEA.cpp
# [ 474/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_MaxsonarSerialLV.cpp
# [ 475/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_USD1_CAN.cpp
# [ 476/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_MSP.cpp
# [ 477/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_MaxsonarI2CXL.cpp
# [ 478/1016] Compiling libraries/AP_RangeFinder/AP_RangeFinder_Lua.cpp
# ...
# [ 844/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.dynamic_node_id.server.AppendEntries_res.c
# [ 845/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/ardupilot.indication.NotifyState.c
# [ 846/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.debug.LogLevel.c
# [ 847/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.debug.KeyValue.c
# [ 848/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/ardupilot.equipment.power.BatteryInfoAux.c
# [ 849/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.SoftwareVersion.c
# [ 850/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.GetTransportStats_req.c
# [ 851/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.GetDirectoryEntryInfo_res.c
# [ 852/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.AccessCommandShell_req.c
# [ 853/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.range_sensor.Measurement.c
# [ 854/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/dronecan.remoteid.System.c
# [ 855/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.ice.reciprocating.CylinderStatus.c
# [ 856/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.gnss.RTCMStream.c
# [ 857/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.esc.RPMCommand.c
# [ 858/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.air_data.StaticPressure.c
# [ 859/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.air_data.Sideslip.c
# [ 860/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.tunnel.Protocol.c
# [ 861/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/ardupilot.gnss.Heading.c
# [ 862/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.camera_gimbal.Status.c
# [ 863/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.navigation.GlobalNavigationSolution.c
# [ 864/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/mppt.OutputEnable_req.c
# [ 865/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.camera_gimbal.GEOPOICommand.c
# [ 866/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.actuator.Status.c
# [ 867/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.CoarseOrientation.c
# [ 868/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/dronecan.sensors.hygrometer.Hygrometer.c
# [ 869/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.dynamic_node_id.server.RequestVote_res.c
# [ 870/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.camera_gimbal.Mode.c
# [ 871/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/dronecan.remoteid.ArmStatus.c
# [ 872/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.BeginFirmwareUpdate_req.c
# [ 873/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.indication.RGB565.c
# [ 874/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.power.PrimaryPowerSupplyStatus.c
# [ 875/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/dronecan.remoteid.SecureCommand_req.c
# [ 876/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.ahrs.Solution.c
# [ 877/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.gnss.ECEFPositionVelocity.c
# [ 878/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.GetDataTypeInfo_res.c
# [ 879/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.GetDataTypeInfo_req.c
# [ 880/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.NodeStatus.c
# [ 881/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.tunnel.Call_req.c
# [ 882/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.Write_res.c
# [ 883/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.param.ExecuteOpcode_res.c
# [ 884/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.actuator.Command.c
# [ 885/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.Panic.c
# [ 886/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.Read_res.c
# [ 887/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.BeginFirmwareUpdate_res.c
# [ 888/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.air_data.RawAirData.c
# [ 889/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.Read_req.c
# [ 890/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.enumeration.Begin_req.c
# [ 891/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.power.CircuitStatus.c
# [ 892/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/ardupilot.indication.SafetyState.c
# [ 893/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.gnss.Fix2.c
# [ 894/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.esc.RawCommand.c
# [ 895/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/com.hex.equipment.flow.Measurement.c
# [ 896/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/ardupilot.indication.Button.c
# [ 897/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.Timestamp.c
# [ 898/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.EntryType.c
# [ 899/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.GetDirectoryEntryInfo_req.c
# [ 900/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.gnss.Fix.c
# [ 901/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.enumeration.Begin_res.c
# [ 902/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.enumeration.Indication.c
# [ 903/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.Delete_req.c
# [ 904/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.air_data.AngleOfAttack.c
# [ 905/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.ahrs.MagneticFieldStrength2.c
# [ 906/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.ice.FuelTankStatus.c
# [ 907/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.air_data.TrueAirspeed.c
# [ 908/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.hardpoint.Command.c
# [ 909/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/cuav.equipment.power.CBAT.c
# [ 910/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.esc.Status.c
# [ 911/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.device.Temperature.c
# [ 912/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.ice.reciprocating.Status.c
# [ 913/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/ardupilot.equipment.trafficmonitor.TrafficReport.c
# [ 914/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.actuator.ArrayCommand.c
# [ 915/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.air_data.IndicatedAirspeed.c
# [ 916/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.dynamic_node_id.server.RequestVote_req.c
# [ 917/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/ardupilot.gnss.RelPosHeading.c
# [ 918/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.Error.c
# [ 919/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.camera_gimbal.AngularCommand.c
# [ 920/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.DataTypeKind.c
# [ 921/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.indication.BeepCommand.c
# [ 922/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.dynamic_node_id.Allocation.c
# [ 923/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.file.Write_req.c
# [ 924/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/ardupilot.equipment.proximity_sensor.Proximity.c
# [ 925/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/mppt.Stream.c
# [ 926/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/dronecan.remoteid.SecureCommand_res.c
# [ 927/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/ardupilot.gnss.Status.c
# [ 928/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.dynamic_node_id.server.Entry.c
# [ 929/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.power.BatteryInfo.c
# [ 930/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.param.Value.c
# [ 931/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/mppt.OutputEnable_res.c
# [ 932/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/com.himark.servo.ServoCmd.c
# [ 933/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.equipment.indication.LightsCommand.c
# [ 934/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/dronecan.remoteid.Location.c
# [ 935/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.RestartNode_req.c
# [ 936/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.HardwareVersion.c
# [ 937/1016] Compiling build/Pixhawk4/modules/DroneCAN/libcanard/dsdlc_generated/src/uavcan.protocol.GetNodeInfo_res.c
# [ 938/1016] Compiling ArduCopter/heli.cpp
# [ 939/1016] Compiling ArduCopter/mode_circle.cpp
# [ 940/1016] Compiling ArduCopter/landing_gear.cpp
# [ 941/1016] Linking build/Pixhawk4/lib/libArduCopter_libs.a
# [ 942/1016] Compiling ArduCopter/mode_stabilize.cpp
# [ 943/1016] Compiling ArduCopter/toy_mode.cpp
# [ 944/1016] Compiling ArduCopter/afs_copter.cpp
# [ 945/1016] Compiling ArduCopter/baro_ground_effect.cpp
# [ 946/1016] Compiling ArduCopter/esc_calibration.cpp
# [ 947/1016] Compiling ArduCopter/mode_drift.cpp
# [ 948/1016] Compiling ArduCopter/mode_autotune.cpp
# [ 949/1016] Compiling ArduCopter/fence.cpp
# [ 950/1016] Compiling ArduCopter/terrain.cpp
# [ 951/1016] Compiling ArduCopter/mode_guided.cpp
# [ 952/1016] Compiling ArduCopter/mode_sport.cpp
# [ 953/1016] Compiling ArduCopter/standby.cpp
# [ 954/1016] Compiling ArduCopter/mode_flowhold.cpp
# [ 955/1016] Compiling ArduCopter/mode_rtl.cpp
# [ 956/1016] Compiling ArduCopter/Copter.cpp
# [ 957/1016] Compiling ArduCopter/mode_zigzag.cpp
# [ 958/1016] Compiling ArduCopter/mode.cpp
# [ 959/1016] Compiling ArduCopter/mode_throw.cpp
# [ 960/1016] Compiling ArduCopter/mode_flip.cpp
# [ 961/1016] Compiling ArduCopter/mode_autorotate.cpp
# [ 962/1016] Compiling ArduCopter/system.cpp
# [ 963/1016] Compiling ArduCopter/avoidance_adsb.cpp
# [ 964/1016] Compiling ArduCopter/events.cpp
# [ 965/1016] Compiling ArduCopter/Parameters.cpp
# [ 966/1016] Compiling ArduCopter/mode_avoid_adsb.cpp
# [ 967/1016] Compiling ArduCopter/takeoff.cpp
# [ 968/1016] Compiling ArduCopter/RC_Channel.cpp
# [ 969/1016] Compiling ArduCopter/navigation.cpp
# [ 970/1016] Compiling ArduCopter/AP_Arming.cpp
# [ 971/1016] Compiling ArduCopter/mode_land.cpp
# [ 972/1016] Compiling ArduCopter/radio.cpp
# [ 973/1016] Compiling ArduCopter/autoyaw.cpp
# [ 974/1016] Compiling ArduCopter/mode_acro_heli.cpp
# [ 975/1016] Compiling ArduCopter/mode_smart_rtl.cpp
# [ 976/1016] Compiling ArduCopter/GCS_Mavlink.cpp
# [ 977/1016] Compiling ArduCopter/sensors.cpp
# [ 978/1016] Compiling ArduCopter/mode_turtle.cpp
# [ 979/1016] Compiling ArduCopter/mode_systemid.cpp
# [ 980/1016] Compiling ArduCopter/mode_stabilize_heli.cpp
# [ 981/1016] Compiling ArduCopter/crash_check.cpp
# [ 982/1016] Compiling ArduCopter/avoidance.cpp
# [ 983/1016] Compiling ArduCopter/takeoff_check.cpp
# [ 984/1016] Compiling ArduCopter/surface_tracking.cpp
# [ 985/1016] Compiling ArduCopter/mode_poshold.cpp
# [ 986/1016] Compiling ArduCopter/mode_althold.cpp
# [ 987/1016] Compiling ArduCopter/Log.cpp
# [ 988/1016] Compiling ArduCopter/motors.cpp
# [ 989/1016] Compiling ArduCopter/commands.cpp
# [ 990/1016] Compiling ArduCopter/GCS_Copter.cpp
# [ 991/1016] Compiling ArduCopter/Attitude.cpp
# [ 992/1016] Compiling ArduCopter/compassmot.cpp
# [ 993/1016] Compiling ArduCopter/inertia.cpp
# [ 994/1016] Compiling ArduCopter/land_detector.cpp
# [ 995/1016] Compiling ArduCopter/mode_auto.cpp
# [ 996/1016] Compiling ArduCopter/mode_loiter.cpp
# [ 997/1016] Compiling ArduCopter/ekf_check.cpp
# [ 998/1016] Compiling ArduCopter/AP_Rally.cpp
# [ 999/1016] Compiling ArduCopter/tuning.cpp
# [1000/1016] Compiling ArduCopter/motor_test.cpp
# [1001/1016] Compiling ArduCopter/mode_guided_nogps.cpp
# [1002/1016] Compiling ArduCopter/mode_follow.cpp
# [1003/1016] Compiling ArduCopter/UserCode.cpp
# [1004/1016] Compiling ArduCopter/precision_landing.cpp
# [1005/1016] Compiling ArduCopter/UserParameters.cpp
# [1006/1016] Compiling ArduCopter/failsafe.cpp
# [1007/1016] Compiling ArduCopter/AP_State.cpp
# [1008/1016] Compiling ArduCopter/mode_brake.cpp
# [1009/1016] Compiling ArduCopter/mode_acro.cpp
# [1010/1016] Linking build/Pixhawk4/bin/arducopter
# [1011/1016] apj_tool build/Pixhawk4/bin/arducopter
# Loaded binary file of length 2889716
# Setting defaults from /home/jetson/ardupilot/libraries/AP_HAL_ChibiOS/hwdef/Pixhawk4/defaults.parm
# Saved binary of length 2889716
# [1012/1016] Generating bin/arducopter.bin
# [1013/1016] app_descriptor build/Pixhawk4/bin/arducopter.bin
# No APP_DESCRIPTOR found
# [1014/1016] apj_gen build/Pixhawk4/bin/arducopter.bin
# [1015/1016] bin cleanup build/Pixhawk4/bin/arducopter.bin
# [1016/1016] Generating bin/arducopter.hex
# Waf: Leaving directory `/home/jetson/ardupilot/build/Pixhawk4'
#
# BUILD SUMMARY
# Build directory: /home/jetson/ardupilot/build/Pixhawk4
# Target          Text (B)  Data (B)  BSS (B)  Total Flash Used (B)  Free Flash (B)  External Flash Used (B)
# ----------------------------------------------------------------------------------------------------------
# bin/arducopter   1715988      3512   389836               1719500          344880  Not Applicable
#
# Build commands will be stored in build/Pixhawk4/compile_commands.json
# 'copter' finished successfully (32m35.188s)

# %% [markdown]
# ## 3. 启动

# %%
#PC端启动
# !dronekit-sitl copter
# Out:
# os: linux, apm: copter, release: stable
# SITL already Downloaded and Extracted.
# Ready to boot.
# Execute: /home/jetson/.dronekit/sitl/copter-3.3/apm --home=-35.363261,149.165230,584,353 --model=quad -I 0
# SITL-0> Started model quad at -35.363261,149.165230,584,353 at speed 1.0
# SITL-0.stderr> bind port 5760 for 0
# Starting sketch 'ArduCopter'
# Serial port 0 on TCP port 5760
# Starting SITL input
# Waiting for connection ....

# %% [markdown]
# ## 4. 测试

# %%
# %cd ~/ardupilot/Tools/autotest/
# !sim_vehicle.py -L RATBeach --out=udp:0.0.0.0:14550 --map –console -v ArduSub
# Out:
# /home/jetson/ardupilot/Tools/autotest
# SIM_VEHICLE: Start
# SIM_VEHICLE: Killing tasks
# SIM_VEHICLE: Starting up at [33.810313, -118.393867, 0.0, 270.0] (RATBeach)
# SIM_VEHICLE: WAF build
# SIM_VEHICLE: Configure waf
# SIM_VEHICLE: "/home/jetson/ardupilot/modules/waf/waf-light" "configure" "--board" "sitl"
# Setting top to                           : /home/jetson/ardupilot
# Setting out to                           : /home/jetson/ardupilot/build
# Autoconfiguration                        : enabled
# Checking for program 'python'            : /usr/bin/python
# Checking for python version >= 3.6.9     : 3.8.10
# Setting board to                         : sitl
# Using toolchain                          : native
# Checking for 'g++' (C++ compiler)        : /usr/lib/ccache/g++
# Checking for 'gcc' (C compiler)          : /usr/lib/ccache/gcc
# Checking for c flags '-MMD'              : yes
# Checking for cxx flags '-MMD'            : yes
# CXX Compiler                             : g++ 9.4.0
# Checking for need to link with librt     : not necessary
# Checking for feenableexcept              : yes
# Enabled OpenDroneID                      : no
# Enabled firmware ID checking             : no
# GPS Debug Logging                        : no
# Enabled custom controller                : yes
# Checking for HAVE_CMATH_ISFINITE         : yes
# Checking for HAVE_CMATH_ISINF            : yes
# Checking for HAVE_CMATH_ISNAN            : yes
# Checking for NEED_CMATH_ISFINITE_STD_NAMESPACE : yes
# Checking for NEED_CMATH_ISINF_STD_NAMESPACE    : yes
# Checking for NEED_CMATH_ISNAN_STD_NAMESPACE    : yes
# Checking for header endian.h                   : yes
# Checking for header byteswap.h                 : yes
# Checking for HAVE_MEMRCHR                      : yes
# Configured VSCode Intellisense:                : no
# DC_DSDL compiler                               : /home/jetson/ardupilot/modules/DroneCAN/dronecan_dsdlc/dronecan_dsdlc.py
# Source is git repository                       : yes
# Update submodules                              : yes
# Checking for program 'git'                     : /usr/bin/git
# Checking for program 'size'                    : /usr/bin/size
# Benchmarks                                     : disabled
# Unit tests                                     : enabled
# Scripting                                      : enabled
# Scripting runtime checks                       : enabled
# Debug build                                    : disabled
# Coverage build                                 : disabled
# Force 32-bit build                             : disabled
# Checking for program 'rsync'                   : /usr/bin/rsync
# 'configure' finished successfully (3.615s)
# {'waf_target': 'bin/ardusub', 'default_params_filename': 'default_params/sub.parm', 'model': 'vectored', 'sitl-port': True}
# SIM_VEHICLE: Building
# SIM_VEHICLE: "/home/jetson/ardupilot/modules/waf/waf-light" "build" "--target" "bin/ardusub"
# Waf: Entering directory `/home/jetson/ardupilot/build/sitl'
# Embedding file locations.txt:Tools/autotest/locations.txt
# Embedding file models/Callisto.json:Tools/autotest/models/Callisto.json
# Embedding file models/plane-3d.parm:Tools/autotest/models/plane-3d.parm
# Embedding file models/plane.parm:Tools/autotest/models/plane.parm
# Embedding file models/xplane_heli.json:Tools/autotest/models/xplane_heli.json
# Embedding file models/xplane_plane.json:Tools/autotest/models/xplane_plane.json
# Waf: Leaving directory `/home/jetson/ardupilot/build/sitl'
#
# BUILD SUMMARY
# Build directory: /home/jetson/ardupilot/build/sitl
# Target       Text (B)  Data (B)  BSS (B)  Total Flash Used (B)  Free Flash (B)  External Flash Used (B)
# -------------------------------------------------------------------------------------------------------
# bin/ardusub   3347258    133509   204456               3480767  Not Applicable  Not Applicable
#
# Build commands will be stored in build/sitl/compile_commands.json
# 'build' finished successfully (5.765s)
# SIM_VEHICLE: Using defaults from (default_params/sub.parm)
# SIM_VEHICLE: Run ArduSub
# SIM_VEHICLE: "/home/jetson/ardupilot/Tools/autotest/run_in_terminal_window.sh" "ArduSub" "/home/jetson/ardupilot/build/sitl/bin/ardusub" "-S" "--model" "vectored" "--speedup" "1" "--slave" "0" "--defaults" "default_params/sub.parm" "--sim-address=127.0.0.1" "-I0" "--home" "33.810313,-118.39386700000001,0.0,270.0"
# RiTW: Starting ArduSub : /home/jetson/ardupilot/build/sitl/bin/ardusub -S --model vectored --speedup 1 --slave 0 --defaults default_params/sub.parm --sim-address=127.0.0.1 -I0 --home 33.810313,-118.39386700000001,0.0,270.0
# SIM_VEHICLE: Run MavProxy
# SIM_VEHICLE: "mavproxy.py" "--out" "127.0.0.1:14550" "--master" "tcp:127.0.0.1:5760" "--sitl" "127.0.0.1:5501" "--out" "udp:0.0.0.0:14550" "--map"
# _IceTransSocketUNIXConnect: Cannot connect to non-local host nano-vm
# _IceTransSocketUNIXConnect: Cannot connect to non-local host nano-vm
# Warning: Tried to connect to session manager, Could not open network socket
# Connect tcp:127.0.0.1:5760 source_system=255
# _IceTransSocketUNIXConnect: Cannot connect to non-local host nano-vm
# _IceTransSocketUNIXConnect: Cannot connect to non-local host nano-vm
# 16时01分40秒: Debug: Failed to connect to session manager: Could not open network socket
# Loaded module map
# Log Directory:
# Telemetry log: mav.tlog
# Waiting for heartbeat from tcp:127.0.0.1:5760
# MAV> Detected vehicle 1:1 on link 0
# online system 1
# STABILIZE> Mode STABILIZE
#
# SIM_VEHICLE: Keyboard Interrupt received ...
# SIM_VEHICLE: Killing tasks
